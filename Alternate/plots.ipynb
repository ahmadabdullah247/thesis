# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.figsize'] = (20, 7)
plt.rcParams['axes.grid'] = True

# %%
x = ['ROH01', 'ROH02', 'ROH03', 'ROH04', 'ROH05', 'ROH07', 'ROH14', 'ROH21', 'ROH30', 'ROH60', 'ROH90']

# %%
lstm_std = [0.0504,0.0588,0.0666,0.0707,0.0763,0.0804,0.0924,0.0977,0.0975,0.1026,0.1078]
lstm_std_attr = [0.0563, 0.0643, 0.0742, 0.0719, 0.0774, 0.0824, 0.0905, 0.0912, 0.0898, 0.0934, 0.0922]
svr_std = [0.0455, 0.0542, 0.0632, 0.0646, 0.0684, 0.0746, 0.0898, 0.1083, 0.1039, 0.1088, 0.1101]
svr_std_attr = [0.055, 0.0641, 0.0695, 0.0729, 0.0762, 0.0781, 0.0851, 0.0857, 0.0869, 0.0905, 0.091]

# %%
plt.plot(x,lstm_std, label='LSTM')
plt.plot(x,lstm_std_attr, label='LSTM Attr')
plt.plot(x,svr_std, label='SVR')
plt.plot(x,svr_std_attr, label='SVR Attr')

plt.xlabel('Reservation on hand')
plt.ylabel('Standard Deviation Error')
plt.legend(loc='best')
plt.show()

# %%
lstm_bias = [0.0108, 0.0129, 0.027, 0.0217, 0.0182, 0.0322, -0.0063, -0.0076, -0.0234, -0.0173, -0.0125]
lstm_bias_attr = [0.0258, 0.0205, 0.0213, 0.0149, 0.0119, 0.0264, 0.0042, -0.0066, -0.0175, -0.032, -0.0383]
svr_bias = [0.0143, 0.0129, 0.0121, 0.0109, 0.0074, 0.0102, -0.0144, -0.0295, 0.0132, 0.0132, 0.0162]
svr_bias_attr = [0.0138, 0.0098, 0.0088, 0.0061, 0.0022, 0.0035, -0.0127, -0.0131, -0.0229, -0.035, -0.0323]

plt.plot(x,lstm_bias, label='LSTM')
plt.plot(x,lstm_bias_attr, label='LSTM Attr')
plt.plot(x,svr_bias, label='SVR')
plt.plot(x,svr_bias_attr, label='SVR Attr')

plt.xlabel('Reservation on hand')
plt.ylabel('Mean Error')
plt.legend(loc='best')
plt.show()

# %%
lstm_mae = [0.0339, 0.04, 0.0516, 0.0524, 0.0542, 0.0633, 0.0577, 0.0619, 0.0621, 0.0677, 0.0724]
lstm_mae_attr = [0.0444, 0.0492, 0.0561, 0.0565, 0.0604, 0.0656, 0.068, 0.0667, 0.0631, 0.0636, 0.0625]
svr_mae = [0.0304, 0.0355, 0.0405, 0.0413, 0.0426, 0.0456, 0.0501, 0.0615, 0.0821, 0.0894, 0.093]
svr_mae_attr = [0.0399, 0.0455, 0.0487, 0.0506, 0.0527, 0.0548, 0.0561, 0.0559, 0.0554, 0.0557, 0.056]

plt.plot(x,lstm_mae, label='LSTM')
plt.plot(x,lstm_mae_attr, label='LSTM Attr')
plt.plot(x,svr_mae, label='SVR')
plt.plot(x,svr_mae_attr, label='SVR Attr')

plt.xlabel('Reservation on hand')
plt.ylabel('MAE')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Group Plots

# %%
group_svr_sde = [0.203, 0.2096, 0.2153, 0.2227, 0.2354, 0.2668, 0.3019, 0.3514, 0.3968, 0.4721, 0.4943]
group_svr_me  = [0.1839, 0.1954, 0.1894, 0.1841, 0.1816, 0.2666, 0.2709, 0.4276, 0.6633, 0.3622, 0.4838]
group_svr_acc = [0.042, 0.0451, 0.0478, 0.0518, 0.0591,0.0758, 0.1082, 0.1427, 0.1835, 0.2506, 0.2495]

group_lstm_sde = [1.384, 1.415, 1.192, 1.144, 1.286, 1.256, 1.157, 1.308, 1.147, 1.132, 1.0146]
group_lstm_me  = [0.60810, 0.73000, 0.64190, -0.0018, 0.40400, 0.08810, 0.51260, 0.64450, 0.59190, 0.70420, 0.42290]
group_lstm_acc = [1.9504,2.165,1.5296,1.4469,1.7374,1.6498,1.4041,1.7179,1.3937,1.3582,1.1573]

# %%
plt.plot(x,group_svr_sde, label='SVR')
plt.plot(x,group_lstm_sde, label='LSTM')

plt.xlabel('Reservation on hand')
plt.ylabel('Standard Deviation Error')
plt.legend(loc='best')
plt.show()

# %%
plt.plot(x,group_svr_me, label='SVR')
plt.plot(x,group_lstm_me, label='LSTM')

plt.xlabel('Reservation on hand')
plt.ylabel('Mean Error')
plt.legend(loc='best')
plt.show()

# %%
plt.plot(x,group_svr_acc, label='SVR')
plt.plot(x,group_lstm_acc, label='LSTM')

plt.xlabel('Reservation on hand')
plt.ylabel('MAE')
plt.legend(loc='best')
plt.show()
