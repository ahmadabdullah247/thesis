# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.figsize'] = (20, 7)
plt.rcParams['axes.grid'] = True

# %%
x = ['DBA 01', 'DBA 02', 'DBA 03', 'DBA 04', 'DBA 05', 'DBA 07', 'DBA 14', 'DBA 21', 'DBA 30', 'DBA 60', 'DBA 90']

# %%
lstm_std = [0.0504,0.0588,0.0666,0.0707,0.0763,0.0804,0.0924,0.0977,0.0975,0.1026,0.1078]
lstm_std_attr = [0.0563, 0.0643, 0.0742, 0.0719, 0.0774, 0.0824, 0.0905, 0.0912, 0.0898, 0.0934, 0.0922]
svr_std = [0.0455, 0.0542, 0.0632, 0.0646, 0.0684, 0.0746, 0.0898, 0.1083, 0.1039, 0.1088, 0.1101]
svr_std_attr = [0.055, 0.0641, 0.0695, 0.0729, 0.0762, 0.0781, 0.0851, 0.0857, 0.0869, 0.0905, 0.091]
rf_std = [0.0432, 0.055, 0.061, 0.0648, 0.0693, 0.0725, 0.0918, 0.0967, 0.1004, 0.1045, 0.109]
rf_std_attr = [0.0442, 0.0577, 0.0635, 0.0635, 0.0689, 0.0703, 0.0795, 0.0852, 0.0898, 0.0882,0.0897]

# %%
plt.plot(x,lstm_std, label='LSTM')
plt.plot(x,lstm_std_attr, linestyle='--', label='LSTM Attr')
plt.plot(x,svr_std, label='SVR')
plt.plot(x,svr_std_attr, linestyle='--', label='SVR Attr')
plt.plot(x,rf_std, label='RFR')
plt.plot(x,rf_std_attr, linestyle='--', label='RFR Attr')


plt.xlabel('Reservations on Hand (ROH)')
plt.ylabel('Standard Deviation Error (SDE)')
plt.legend(loc='best')
plt.show()

# %%
lstm_bias = [0.0108, 0.0129, 0.027, 0.0217, 0.0182, 0.0322, -0.0063, -0.0076, -0.0234, -0.0173, -0.0125]
lstm_bias_attr = [0.0258, 0.0205, 0.0213, 0.0149, 0.0119, 0.0264, 0.0042, -0.0066, -0.0175, -0.032, -0.0383]
svr_bias = [0.0143, 0.0129, 0.0121, 0.0109, 0.0074, 0.0102, -0.0144, -0.0295, 0.0132, 0.0132, 0.0162]
svr_bias_attr = [0.0138, 0.0098, 0.0088, 0.0061, 0.0022, 0.0035, -0.0127, -0.0131, -0.0229, -0.035, -0.0323]
rf_bias = [0.0115, 0.0141, 0.013, 0.0138, 0.0157, 0.0143, 0.0053, -0.0063, -0.0137, -0.0153, -0.0126]
rf_bias_attr = [0.0129, 0.0131, 0.0117, 0.014, 0.0159, 0.0142, -0.007, -0.0226, -0.0292, -0.0262, -0.0262]

plt.plot(x,lstm_bias, label='LSTM')
plt.plot(x,lstm_bias_attr, linestyle='--', label='LSTM Attr')
plt.plot(x,svr_bias, label='SVR')
plt.plot(x,svr_bias_attr, linestyle='--', label='SVR Attr')
plt.plot(x,rf_bias, label='RFR')
plt.plot(x,rf_bias_attr, linestyle='--', label='RFR Attr')



plt.xlabel('Reservations on Hand (ROH)')
plt.ylabel('Mean Error (ME)')
plt.legend(loc='best')
plt.show()

# %%
lstm_mae = [0.0339, 0.04, 0.0516, 0.0524, 0.0542, 0.0633, 0.0577, 0.0619, 0.0621, 0.0677, 0.0724]
lstm_mae_attr = [0.0444, 0.0492, 0.0561, 0.0565, 0.0604, 0.0656, 0.068, 0.0667, 0.0631, 0.0636, 0.0625]
svr_mae = [0.0304, 0.0355, 0.0405, 0.0413, 0.0426, 0.0456, 0.0501, 0.0615, 0.0821, 0.0894, 0.093]
svr_mae_attr = [0.0399, 0.0455, 0.0487, 0.0506, 0.0527, 0.0548, 0.0561, 0.0559, 0.0554, 0.0557, 0.056]
rf_mae = [0.0317, 0.0382, 0.0393, 0.0439, 0.0468, 0.0482, 0.0579, 0.0629, 0.065, 0.0703, 0.0737]
rf_mae_attr = [0.0335, 0.0411, 0.0416, 0.0445, 0.049, 0.0492, 0.052, 0.0548, 0.0558, 0.0515, 0.0523, ]

plt.plot(x,lstm_mae, label='LSTM')
plt.plot(x,lstm_mae_attr, linestyle='--', label='LSTM Attr')
plt.plot(x,svr_mae, label='SVR')
plt.plot(x,svr_mae_attr, linestyle='--', label='SVR Attr')
plt.plot(x,rf_mae, label='RFR')
plt.plot(x,rf_mae_attr, linestyle='--', label='RFR Attr')

plt.xlabel('Reservation on hand (ROH)')
plt.ylabel('Mean Absolute Error (MAE)')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Group Plots

# %%
group_sde_lstm = [1.384, 1.4159, 1.192, 1.144, 1.2869, 1.2561, 1.1576, 1.3081, 1.1475, 1.1325, 1.0146]
group_me_lstm = [0.6081, 0.73, 0.6419, -0.0018, 0.404, 0.0881, 0.5126, 0.6445, 0.5919, 0.7042, 0.4229]
group_mae_lstm = [1.1219, 1.0538, 1.0054, 0.9476, 1.014, 1.0232, 0.9108, 1.0369, 0.9218, 0.8967, 0.8445]

group_sde_rfr = [0.0697, 0.1021, 0.1109, 0.121, 0.1387, 0.1459, 0.2596, 0.3317, 0.3824, 0.4965, 0.4336]
group_me_rfr = [0.0275, 0.0793, 0.0761,-0.0159, -0.0352, -0.029, 0.1448, 0.3325, 0.5872, 0.397, 0.4772]
group_mae_rfr = [0.0471, 0.068, 0.0793, 0.0891, 0.1047, 0.1113, 0.1861, 0.2502, 0.3108, 0.3953, 0.356]

group_sde_svr = [0.203, 0.2096, 0.2153, 0.2227, 0.2354, 0.2668, 0.3019, 0.3514, 0.3968, 0.4721, 0.4943]
group_me_svr = [0.1839, 0.1954, 0.1894, 0.1841, 0.1816, 0.2666, 0.2709, 0.4276, 0.6633, 0.3622, 0.4838]
group_mae_svr = [0.1202, 0.1308, 0.1399, 0.1486, 0.1632, 0.1858, 0.2373, 0.2773, 0.3171, 0.3915, 0.3835]

# %%
plt.plot(x,group_sde_svr, label='SVR')
plt.plot(x,group_sde_rfr, label='RFR')
plt.plot(x,group_sde_lstm, label='LSTM')

plt.xlabel('Reservations on Hand (ROH)')
plt.ylabel('Standard Deviation Error (SDE)')
plt.legend(loc='best')
plt.show()

# %%
plt.plot(x,group_me_svr, label='SVR')
plt.plot(x,group_me_rfr, label='RFR')
plt.plot(x,group_me_lstm, label='LSTM')

plt.xlabel('Reservations on Hand (ROH)')
plt.ylabel('Mean Error (ME)')
plt.legend(loc='best')
plt.show()

# %%
plt.plot(x,group_mae_svr, label='SVR')
plt.plot(x,group_mae_rfr, label='RFR')
plt.plot(x,group_mae_lstm, label='LSTM')

plt.xlabel('Reservations on Hand (ROH)')
plt.ylabel('Mean Absolute Error (MAE)')
plt.legend(loc='best')
plt.show()
